# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("../data/predtrain.csv")
test = pd.read_csv("../data/predtest.csv")

# %%
train.head()
# Out:
#    id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male              0     Yes        Yes      29          Yes
# 1   1    Male              0     Yes        Yes      58          Yes
# 2   2    Male              0     Yes         No      58          Yes
# 3   3  Female              0      No         No       1          Yes
# 4   4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL            Yes  ...              Yes
# 1            No             DSL            Yes  ...               No
# 2           Yes     Fiber optic             No  ...               No
# 3            No     Fiber optic             No  ...               No
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
test.head()
# Out:
#        id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  594194  Female              0     Yes         No      72          Yes
# 1  594195  Female              0     Yes         No      71          Yes
# 2  594196    Male              0      No         No      12          Yes
# 3  594197    Male              0     Yes        Yes      71          Yes
# 4  594198  Female              0      No         No      15          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                  Yes                  Yes
# 1            No              No  No internet service  No internet service
# 2            No             DSL                  Yes                  Yes
# 3           Yes             DSL                  Yes                   No
# 4            No     Fiber optic                  Yes                   No
#
#       DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
train["Churn"].value_counts()
# Out:
# Churn
# No     460377
# Yes    133817
# Name: count, dtype: int64

# %%
train["MonthlyCharges"].value_counts()
# Out:
# MonthlyCharges
# 20.05     7436
# 19.95     5718
# 19.70     5705
# 20.00     5493
# 19.85     5114
#           ...
# 28.20        1
# 37.15        1
# 18.45        1
# 112.05       1
# 46.15        1
# Name: count, Length: 1921, dtype: int64

# %%
train["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Electronic check             215372
# Credit card (automatic)      133705
# Mailed check                 123757
# Bank transfer (automatic)    121360
# Name: count, dtype: int64

# %%
train["PaperlessBilling"].value_counts()
# Out:
# PaperlessBilling
# Yes    365579
# No     228615
# Name: count, dtype: int64

# %%
train["Contract"].value_counts()
# Out:
# Contract
# Month-to-month    298918
# Two year          186943
# One year          108333
# Name: count, dtype: int64

# %%
train["StreamingMovies"].value_counts()
# Out:
# StreamingMovies
# Yes                    241435
# No                     212032
# No internet service    140727
# Name: count, dtype: int64

# %%
train["StreamingTV"].value_counts()
# Out:
# StreamingTV
# Yes                    240301
# No                     213166
# No internet service    140727
# Name: count, dtype: int64

# %%
train["TechSupport"].value_counts()
# Out:
# TechSupport
# No                     288571
# Yes                    164896
# No internet service    140727
# Name: count, dtype: int64

# %%
train["DeviceProtection"].value_counts()
# Out:
# DeviceProtection
# No                     247377
# Yes                    206090
# No internet service    140727
# Name: count, dtype: int64

# %%
train["OnlineBackup"].value_counts()
# Out:
# OnlineBackup
# No                     250083
# Yes                    203384
# No internet service    140727
# Name: count, dtype: int64

# %%
train["OnlineSecurity"].value_counts()
# Out:
# OnlineSecurity
# No                     289474
# Yes                    163993
# No internet service    140727
# Name: count, dtype: int64

# %%
train["InternetService"].value_counts()
# Out:
# InternetService
# Fiber optic    272386
# DSL            181081
# No             140727
# Name: count, dtype: int64

# %%
train["MultipleLines"].value_counts()
# Out:
# MultipleLines
# No                  283384
# Yes                 274509
# No phone service     36301
# Name: count, dtype: int64

# %%
train["PhoneService"].value_counts()
# Out:
# PhoneService
# Yes    557893
# No      36301
# Name: count, dtype: int64

# %%
train["tenure"].value_counts()
# Out:
# tenure
# 72    56411
# 1     29182
# 71    20763
# 2     16766
# 3     13478
#       ...
# 40     4203
# 21     3862
# 44     3496
# 39     3396
# 36     2562
# Name: count, Length: 72, dtype: int64

# %%
train["Dependents"].value_counts()
# Out:
# Dependents
# No     414362
# Yes    179832
# Name: count, dtype: int64

# %%
train["Partner"].value_counts()
# Out:
# Partner
# Yes    309554
# No     284640
# Name: count, dtype: int64

# %%
train["gender"].value_counts()
# Out:
# gender
# Female    298738
# Male      295456
# Name: count, dtype: int64

# %%
train["SeniorCitizen"].value_counts()
# Out:
# SeniorCitizen
# 0    526395
# 1     67799
# Name: count, dtype: int64

# %%
train["Churn"].dtype
train["Churn"]= train["Churn"].map({"Yes":1, "No":0})

# %%
cat= {"Electronic check":1, "Credit card (automatic)": 2, "Mailed check":3, "Bank transfer (automatic)":4}

train["PaymentMethod"] = train["PaymentMethod"].map(cat)
test["PaymentMethod"] = test["PaymentMethod"].map(cat)

# %%
train["PaperlessBilling"].value_counts()
# Out:
# PaperlessBilling
# Yes    365579
# No     228615
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0}
train["PaperlessBilling"] = train["PaperlessBilling"].map(cat)
test["PaperlessBilling"] = test["PaperlessBilling"].map(cat)

# %%
train["Contract"].value_counts()
# Out:
# Contract
# Month-to-month    298918
# Two year          186943
# One year          108333
# Name: count, dtype: int64

# %%
cat = {"Month-to-month":0, "One year": 1, "Two year":2}
train["Contract"] = train["Contract"].map(cat)
test["Contract"] = test["Contract"].map(cat)

# %%
train["StreamingMovies"].value_counts()
# Out:
# StreamingMovies
# Yes                    241435
# No                     212032
# No internet service    140727
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0, "No internet service": 2}
train["StreamingMovies"] = train["StreamingMovies"].map(cat)
test["StreamingMovies"] = test["StreamingMovies"].map(cat)

# %%
train["StreamingTV"].value_counts()
# Out:
# StreamingTV
# Yes                    240301
# No                     213166
# No internet service    140727
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0, "No internet service": 2}
train["StreamingTV"] = train["StreamingTV"].map(cat)
test["StreamingTV"] = test["StreamingTV"].map(cat)

# %%
train["TechSupport"].value_counts()
# Out:
# TechSupport
# No                     288571
# Yes                    164896
# No internet service    140727
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0, "No internet service": 2}
train["TechSupport"] = train["TechSupport"].map(cat)
test["TechSupport"] = test["TechSupport"].map(cat)

# %%
train["DeviceProtection"].value_counts()
# Out:
# DeviceProtection
# No                     247377
# Yes                    206090
# No internet service    140727
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0, "No internet service": 2}
train["DeviceProtection"] = train["DeviceProtection"].map(cat)
test["DeviceProtection"] = test["DeviceProtection"].map(cat)

# %%
train["OnlineBackup"].value_counts()
# Out:
# OnlineBackup
# No                     250083
# Yes                    203384
# No internet service    140727
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0, "No internet service": 2}
train["OnlineBackup"] = train["OnlineBackup"].map(cat)
test["OnlineBackup"] = test["OnlineBackup"].map(cat)

# %%
train["OnlineSecurity"].value_counts()
# Out:
# OnlineSecurity
# No                     289474
# Yes                    163993
# No internet service    140727
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0, "No internet service": 2}
train["OnlineSecurity"] = train["OnlineSecurity"].map(cat)
test["OnlineSecurity"] = test["OnlineSecurity"].map(cat)

# %%
train["InternetService"].value_counts()
# Out:
# InternetService
# Fiber optic    272386
# DSL            181081
# No             140727
# Name: count, dtype: int64

# %%
cat = {"Fiber optic":1, "No":0, "DSL": 2}
train["InternetService"] = train["InternetService"].map(cat)
test["InternetService"] = test["InternetService"].map(cat)

# %%
train["MultipleLines"].value_counts()
# Out:
# MultipleLines
# No                  283384
# Yes                 274509
# No phone service     36301
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0, "No phone service": 2}
train["MultipleLines"] = train["MultipleLines"].map(cat)
test["MultipleLines"] = test["MultipleLines"].map(cat)

# %%
train["PhoneService"].value_counts()
# Out:
# PhoneService
# Yes    557893
# No      36301
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0}
train["PhoneService"] = train["PhoneService"].map(cat)
test["PhoneService"] = test["PhoneService"].map(cat)

# %%
train["Dependents"].value_counts()
# Out:
# Dependents
# No     414362
# Yes    179832
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0}
train["Dependents"] = train["Dependents"].map(cat)
test["Dependents"] = test["Dependents"].map(cat)

# %%
train["Partner"].value_counts()
# Out:
# Partner
# Yes    309554
# No     284640
# Name: count, dtype: int64

# %%
cat = {"Yes":1, "No":0}
train["Partner"] = train["Partner"].map(cat)
test["Partner"] = test["Partner"].map(cat)

# %%
train["gender"].value_counts()
# Out:
# gender
# Female    298738
# Male      295456
# Name: count, dtype: int64

# %%
cat = {"Female":1, "Male":0}
train["gender"] = train["gender"].map(cat)
test["gender"] = test["gender"].map(cat)

# %%
train.drop("id", axis=1, inplace=True)
test.drop("id", axis=1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 594194 entries, 0 to 594193
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   gender            594194 non-null  int64
#  1   SeniorCitizen     594194 non-null  int64
#  2   Partner           594194 non-null  int64
#  3   Dependents        594194 non-null  int64
#  4   tenure            594194 non-null  int64
#  5   PhoneService      594194 non-null  int64
#  6   MultipleLines     594194 non-null  int64
#  7   InternetService   594194 non-null  int64
#  8   OnlineSecurity    594194 non-null  int64
#  9   OnlineBackup      594194 non-null  int64
#  10  DeviceProtection  594194 non-null  int64
#  11  TechSupport       594194 non-null  int64
#  12  StreamingTV       594194 non-null  int64
#  13  StreamingMovies   594194 non-null  int64
#  14  Contract          594194 non-null  int64
#  15  PaperlessBilling  594194 non-null  int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 254655 entries, 0 to 254654
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   gender            254655 non-null  int64
#  1   SeniorCitizen     254655 non-null  int64
#  2   Partner           254655 non-null  int64
#  3   Dependents        254655 non-null  int64
#  4   tenure            254655 non-null  int64
#  5   PhoneService      254655 non-null  int64
#  6   MultipleLines     254655 non-null  int64
#  7   InternetService   254655 non-null  int64
#  8   OnlineSecurity    254655 non-null  int64
#  9   OnlineBackup      254655 non-null  int64
#  10  DeviceProtection  254655 non-null  int64
#  11  TechSupport       254655 non-null  int64
#  12  StreamingTV       254655 non-null  int64
#  13  StreamingMovies   254655 non-null  int64
#  14  Contract          254655 non-null  int64
#  15  PaperlessBilling  254655 non-null  int64
# ...

# %%
train.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
train.describe()
# Out:
#               gender  SeniorCitizen        Partner     Dependents  \
# count  594194.000000  594194.000000  594194.000000  594194.000000
# mean        0.502762       0.114102       0.520965       0.302649
# std         0.499993       0.317936       0.499561       0.459405
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       1.000000       0.000000
# 75%         1.000000       0.000000       1.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#               tenure   PhoneService  MultipleLines  InternetService  \
# count  594194.000000  594194.000000  594194.000000    594194.000000
# mean       36.577258       0.938907       0.584171         1.067914
# std        25.061922       0.239501       0.604236         0.732786
# min         1.000000       0.000000       0.000000         0.000000
# ...
